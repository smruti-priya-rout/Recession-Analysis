# %%
#import panda libirary
import pandas as pd
#import matplot libiary for plot graph

import matplotlib.pyplot as plt

# %%
#Load the dataset

data=pd.read_csv("recessiondata.csv")
#print first 5 
data.head()
# Out:
#    Year Quarter  GDP_Growth  Inflation  Industrial_Production  Job_Market  \
# 0  2016      Q1    3.866202   5.795522               4.063915       72806
# 1  2013      Q1    6.624839   4.008880               0.301156       51465
# 2  2022      Q4    3.469627   6.322668              -3.622371       64109
# 3  2020      Q3    3.907552   1.415962              -1.309438       53528
# 4  2017      Q4    1.586789   1.885589               2.220974       39230
#
#    Recession_Indicator
# 0                    0
# 1                    0
# 2                    0
# 3                    1
# 4                    0

# %%
#check the data information and description
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   3000 non-null   int64
#  1   Quarter                3000 non-null   object
#  2   GDP_Growth             3000 non-null   float64
#  3   Inflation              3000 non-null   float64
#  4   Industrial_Production  3000 non-null   float64
#  5   Job_Market             3000 non-null   int64
#  6   Recession_Indicator    3000 non-null   int64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 164.2+ KB
#               Year   GDP_Growth    Inflation  Industrial_Production  \
# count  3000.000000  3000.000000  3000.000000            3000.000000
# mean   2015.940333     4.918144     7.613516              -0.014247
# std       3.782972     2.898376     4.307260               2.891739
# min    2010.000000     0.001865     0.020333              -4.998148
# 25%    2013.000000     2.400504     3.987357              -2.442352
# 50%    2016.000000     4.905868     7.699130              -0.040723
# 75%    2019.000000     7.417076    11.368153               2.435992
# max    2022.000000     9.998492    14.996273               4.996356
#
#          Job_Market  Recession_Indicator
# count   3000.000000          3000.000000
# mean   46380.929000             0.131667
# std    25100.201941             0.338184
# min     3018.000000             0.000000
# 25%    24958.500000             0.000000
# 50%    46581.500000             0.000000
# 75%    67982.500000             0.000000
# max    89998.000000             1.000000

# %%
#check the dataset having a  Null values or not

data.isnull().sum()
# Out:
# Year                     0
# Quarter                  0
# GDP_Growth               0
# Inflation                0
# Industrial_Production    0
# Job_Market               0
# Recession_Indicator      0
# dtype: int64

# %%
#There is no null values on our dataset so our  data is clean 
#if Data set  have Null values use dropna to remove null values
#Transform Quarter character values into integer for numerical data

X=data[['Year','Quarter','GDP_Growth','Inflation', 'Industrial_Production', 'Job_Market']]

# %%
#Check X values
X
# Out:
#       Year Quarter  GDP_Growth  Inflation  Industrial_Production  Job_Market
# 0     2016      Q1    3.866202   5.795522               4.063915       72806
# 1     2013      Q1    6.624839   4.008880               0.301156       51465
# 2     2022      Q4    3.469627   6.322668              -3.622371       64109
# 3     2020      Q3    3.907552   1.415962              -1.309438       53528
# 4     2017      Q4    1.586789   1.885589               2.220974       39230
# ...    ...     ...         ...        ...                    ...         ...
# 2995  2021      Q1    3.154164  12.653804               0.783076       43332
# 2996  2020      Q3    6.825993   2.673752               2.006138       10066
# 2997  2017      Q4    8.714885  13.569079               1.546320       42313
# 2998  2011      Q4    2.374860   5.110002              -4.509416       70857
# 2999  2015      Q1    9.789196   5.656680              -3.963961       48900
#
# [3000 rows x 6 columns]

# %%
y=data['Recession_Indicator']

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 2995    1
# 2996    1
# 2997    0
# 2998    0
# 2999    0
# Name: Recession_Indicator, Length: 3000, dtype: int64

# %%
#load data

df=data

#Histogram for GDP Growth

plt.figure(figsize=(8,6))
plt.hist(df['GDP_Growth'],bins=10,color='Green',edgecolor='black')
plt.title('Histogram of GDP Growth')
plt.xlabel('GDP Growth (%)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#Histogram for Inflation
plt.figure(figsize=(8, 6))
plt.hist(df['Inflation'], bins=10, color='orange', edgecolor='black')
plt.title('Histogram of Inflation')
plt.xlabel('Inflation (%)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Histogram for Industrial Production
plt.figure(figsize=(8, 6))
plt.hist(df['Industrial_Production'], bins=10, color='blue', edgecolor='black')
plt.title('Histogram of Industrial Production')
plt.xlabel('Industrial Production')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %%
# Histogram for Job Market
plt.figure(figsize=(8, 6))
plt.hist(df['Job_Market'], bins=10, color='red', edgecolor='black')
plt.title('Histogram of Job Market')
plt.xlabel('Job Market Index')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %%
# Grouping by year and counting occurrences of recession
recession_counts = df.groupby('Year')['Recession_Indicator'].sum()

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(recession_counts.index.astype(str), recession_counts, color='orange')
plt.title('Frequency of Recession by Year')
plt.xlabel('Year')
plt.ylabel('Recession Frequency')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout() 
plt.show()

# %%
# Convert Year and Quarter to datetime
df['Date'] = pd.to_datetime(df['Year'].astype(str) + df['Quarter'])

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Recession_Indicator'], marker='o', linestyle='-', color='green')
plt.title('Recession Occurrences Over Time')
plt.xlabel('Date')
plt.ylabel('Recession Indicator (1: Recession, 0: No Recession)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_18604\3238251421.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Year'].astype(str) + df['Quarter'])

# %%
# Create a scatter plot to show Inflation vs GDP
plt.figure(figsize=(10, 6))
plt.scatter(df['Inflation'], df['GDP_Growth'], c=df['Industrial_Production'], cmap='magma')
plt.xlabel('Inflation')
plt.ylabel('GDP Growth')
plt.title('Scatter Plot of Inflation vs. GDP Growth (Color-mapped by Industrial Production)')
plt.colorbar(label='Industrial Production')
plt.show()

# %%
# Filter dataframe to include only years where recession occurred
recession_years = df[df['Recession_Indicator'] == 1]

# Plotting
plt.figure(figsize=(10, 6))
quarters = ['Q1', 'Q2', 'Q3', 'Q4']

for quarter in quarters:
    # Count occurrences of recession indicator for each quarter
    count_0 = len(recession_years[recession_years['Quarter'] == quarter][recession_years['Recession_Indicator'] == 0])
    count_1 = len(recession_years[recession_years['Quarter'] == quarter][recession_years['Recession_Indicator'] == 1])

    # Plotting bars
    plt.bar(quarter, count_0, color='blue', label='No Recession' if quarter == 'Q1' else '')
    plt.bar(quarter, count_1, bottom=count_0, color='Orange', label='Recession' if quarter == 'Q1' else '')

plt.title('Recession Occurrences Over Quarters')
plt.xlabel('Quarter')
plt.ylabel('Frequency')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_18604\3025607679.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   count_0 = len(recession_years[recession_years['Quarter'] == quarter][recession_years['Recession_Indicator'] == 0])
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_18604\3025607679.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   count_1 = len(recession_years[recession_years['Quarter'] == quarter][recession_years['Recession_Indicator'] == 1])
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_18604\3025607679.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   count_0 = len(recession_years[recession_years['Quarter'] == quarter][recession_years['Recession_Indicator'] == 0])
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_18604\3025607679.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   count_1 = len(recession_years[recession_years['Quarter'] == quarter][recession_years['Recession_Indicator'] == 1])
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_18604\3025607679.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   count_0 = len(recession_years[recession_years['Quarter'] == quarter][recession_years['Recession_Indicator'] == 0])
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_18604\3025607679.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   count_1 = len(recession_years[recession_years['Quarter'] == quarter][recession_years['Recession_Indicator'] == 1])
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_18604\3025607679.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   count_0 = len(recession_years[recession_years['Quarter'] == quarter][recession_years['Recession_Indicator'] == 0])
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_18604\3025607679.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   count_1 = len(recession_years[recession_years['Quarter'] == quarter][recession_years['Recession_Indicator'] == 1])

# %%
# Filter dataframe to include only the last 5 years
last_5_years_df = df[df['Year'] >= df['Year'].max() - 4]

# Grouping by year and quarter and counting occurrences of recession
recession_counts = last_5_years_df.groupby(['Year', 'Quarter'])['Recession_Indicator'].sum().unstack(fill_value=0)

# Plotting
plt.figure(figsize=(10, 6))

quarters = ['Q1', 'Q2', 'Q3', 'Q4']
bar_width = 0.2
opacity = 0.8
index = range(len(recession_counts))

colors = ['magenta', 'indigo', 'gold', 'brown']

for i, quarter in enumerate(quarters):
    plt.bar([x + i * bar_width for x in index], recession_counts[quarter], bar_width,
            alpha=opacity, color=colors[i], label=quarter)

plt.xlabel('Year')
plt.ylabel('Recession Frequency')
plt.title('Recession Occurrences Over Last 5 Years')
plt.xticks(index, recession_counts.index)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Grouping by year and quarter and counting occurrences of recession
recession_counts = df.groupby(['Year', 'Quarter'])['Recession_Indicator'].sum().unstack(fill_value=0)

# Plotting
plt.figure(figsize=(12, 6))

quarters = ['Q1', 'Q2', 'Q3', 'Q4']
bar_width = 0.15
opacity = 0.8
index = range(len(recession_counts))

colors = ['darkviolet', 'greenyellow', 'steelblue', 'red']

for i, quarter in enumerate(quarters):
    plt.bar([x + i * bar_width for x in index], recession_counts[quarter], bar_width,
            alpha=opacity, color=colors[i], label=quarter)

plt.xlabel('Year')
plt.ylabel('Recession Frequency')
plt.title('Recession Occurrences Over All Years')
plt.xticks(index, recession_counts.index, rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Extract the relevant columns
quarters = df['Year'].astype(str) + '-' + df['Quarter']
inflation = df['Inflation']
gdp_growth = df['GDP_Growth']
industrial_production = df['Industrial_Production']

# %%
# Create a line graph
plt.figure(figsize=(12, 6))
plt.plot(quarters, inflation, label='Inflation', marker='o', color='skyblue')
plt.plot(quarters, gdp_growth, label='GDP Growth', marker='o',color='lime')
plt.plot(quarters, industrial_production, label='Industrial Production', marker='o',color='blueviolet')

plt.xlabel('Quarter')
plt.ylabel('Values')
plt.title('Time Series of Economic Indicators')
plt.xticks(rotation=270)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
